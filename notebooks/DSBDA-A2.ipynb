# %% [markdown]
# # Assignment No 2 : Data Wrangling 2

# %% [markdown]
# # 1. Import Required Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 2. Load the dataset into dataframe

# %%
data = {
    'math_score': [71.0, 63.0, 71.0, 77.0, 63.0, np.nan, 66.0, 50.0, 60.0, 64.0, 63.0, 66.0, 60.0, 72.0, 60.0, 69.0, 72.0, 90.0, 70.0, 66.0, 61.0, np.nan, 65.0, 63.0, 78.0, 71.0, 78.0, 67.0, 75.0, 73.0],
    'reading_score': [78, 86, 92, 95, 81, 92, 75, 100, 90, 89, 81, 95, 88, 80, 76, 83, 80, 95, 89, 91, 75, 77, 95, 86, 95, 84, 78, 79, 79, 78],
    'writing_score': [65.0, 71.0, 64.0, 68.0, 70.0, np.nan, 67.0, 68.0, 61.0, 72.0, 62.0, 77.0, 73.0, 69.0, np.nan, 69.0, 20.0, 66.0, 73.0, 77.0, 74.0, 79.0, 60.0, 78.0, 66.0, 72.0, 73.0, 67.0, np.nan, np.nan],
    'placement_score': [99.0, 100.0, 76.0, 84.0, 76.0, 89.0, 93.0, 200.0, 87.0, 80.0, 95.0, 90.0, 91.0, 98.0, 82.0, np.nan, 75.0, 85.0, 90.0, 100.0, 76.0, 82.0, 100.0, 82.0, np.nan, 89.0, 87.0, 89.0, 97.0, 75.0],
    'club_join_date': [2018.0, np.nan, 2021.0, 2021.0, 2021.0, 2020.0, 2019.0, 2015.0, 2021.0, 2019.0, 2021.0, 2020.0, 2020.0, 2021.0, 2020.0, 2019.0, 2021.0, 2002.0, 2020.0, 2020.0, np.nan, 2018.0, 2021.0, 2019.0, 2019.0, 2018.0, 2018.0, 2018.0, 2020.0, 2020.0],
    'placement_offer_count': [3.0, 3.0, 2.0, 2.0, 2.0, 3.0, 3.0, 3.0, 3.0, 2.0, 1.0, 3.0, 3.0, 3.0, 2.0, 1.0, 2.0, np.nan, 3.0, 3.0, 2.0, 3.0, 3.0, 2.0, 1.0, 3.0, 3.0, 3.0, 3.0, 2.0]
}

df = pd.DataFrame(data)

# %% [markdown]
# # Check the dimensions of dataframe

# %%
df.shape
# Out:
# (30, 6)

# %% [markdown]
# # Check the number of null values in each column

# %%
df.isnull().sum()
# Out:
# math_score               2
# reading_score            0
# writing_score            4
# placement_score          2
# club_join_date           2
# placement_offer_count    1
# dtype: int64

# %%
df.isnull()
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_date  \
# 0        False          False          False            False           False
# 1        False          False          False            False            True
# 2        False          False          False            False           False
# 3        False          False          False            False           False
# 4        False          False          False            False           False
# 5         True          False           True            False           False
# 6        False          False          False            False           False
# 7        False          False          False            False           False
# 8        False          False          False            False           False
# 9        False          False          False            False           False
# 10       False          False          False            False           False
# 11       False          False          False            False           False
# 12       False          False          False            False           False
# 13       False          False          False            False           False
# 14       False          False           True            False           False
# 15       False          False          False             True           False
# 16       False          False          False            False           False
# 17       False          False          False            False           False
# 18       False          False          False            False           False
# 19       False          False          False            False           False
# 20       False          False          False            False            True
# 21        True          False          False            False           False
# 22       False          False          False            False           False
# 23       False          False          False            False           False
# 24       False          False          False             True           False
# 25       False          False          False            False           False
# 26       False          False          False            False           False
# 27       False          False          False            False           False
# 28       False          False           True            False           False
# 29       False          False           True            False           False
#
#     placement_offer_count
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# 5                   False
# 6                   False
# 7                   False
# 8                   False
# 9                   False
# 10                  False
# 11                  False
# 12                  False
# 13                  False
# 14                  False
# 15                  False
# 16                  False
# 17                   True
# 18                  False
# 19                  False
# 20                  False
# 21                  False
# 22                  False
# 23                  False
# 24                  False
# 25                  False
# 26                  False
# 27                  False
# 28                  False
# 29                  False

# %% [markdown]
# # Handling missing/null values

# %%
df['math_score']=df['math_score'].interpolate()
df
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_date  \
# 0         71.0             78           65.0             99.0          2018.0
# 1         63.0             86           71.0            100.0             NaN
# 2         71.0             92           64.0             76.0          2021.0
# 3         77.0             95           68.0             84.0          2021.0
# 4         63.0             81           70.0             76.0          2021.0
# 5         64.5             92            NaN             89.0          2020.0
# 6         66.0             75           67.0             93.0          2019.0
# 7         50.0            100           68.0            200.0          2015.0
# 8         60.0             90           61.0             87.0          2021.0
# 9         64.0             89           72.0             80.0          2019.0
# 10        63.0             81           62.0             95.0          2021.0
# 11        66.0             95           77.0             90.0          2020.0
# 12        60.0             88           73.0             91.0          2020.0
# 13        72.0             80           69.0             98.0          2021.0
# 14        60.0             76            NaN             82.0          2020.0
# 15        69.0             83           69.0              NaN          2019.0
# 16        72.0             80           20.0             75.0          2021.0
# 17        90.0             95           66.0             85.0          2002.0
# 18        70.0             89           73.0             90.0          2020.0
# 19        66.0             91           77.0            100.0          2020.0
# 20        61.0             75           74.0             76.0             NaN
# 21        63.0             77           79.0             82.0          2018.0
# 22        65.0             95           60.0            100.0          2021.0
# 23        63.0             86           78.0             82.0          2019.0
# 24        78.0             95           66.0              NaN          2019.0
# 25        71.0             84           72.0             89.0          2018.0
# 26        78.0             78           73.0             87.0          2018.0
# 27        67.0             79           67.0             89.0          2018.0
# 28        75.0             79            NaN             97.0          2020.0
# 29        73.0             78            NaN             75.0          2020.0
#
#     placement_offer_count
# 0                     3.0
# 1                     3.0
# 2                     2.0
# 3                     2.0
# 4                     2.0
# 5                     3.0
# 6                     3.0
# 7                     3.0
# 8                     3.0
# 9                     2.0
# 10                    1.0
# 11                    3.0
# 12                    3.0
# 13                    3.0
# 14                    2.0
# 15                    1.0
# 16                    2.0
# 17                    NaN
# 18                    3.0
# 19                    3.0
# 20                    2.0
# 21                    3.0
# 22                    3.0
# 23                    2.0
# 24                    1.0
# 25                    3.0
# 26                    3.0
# 27                    3.0
# 28                    3.0
# 29                    2.0

# %%
df.isnull().sum()
# Out:
# math_score               0
# reading_score            0
# writing_score            4
# placement_score          2
# club_join_date           2
# placement_offer_count    1
# dtype: int64

# %%
df['writing_score'] = df['writing_score'].fillna(method='ffill')
df
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_date  \
# 0         71.0             78           65.0             99.0          2018.0
# 1         63.0             86           71.0            100.0             NaN
# 2         71.0             92           64.0             76.0          2021.0
# 3         77.0             95           68.0             84.0          2021.0
# 4         63.0             81           70.0             76.0          2021.0
# 5         64.5             92           70.0             89.0          2020.0
# 6         66.0             75           67.0             93.0          2019.0
# 7         50.0            100           68.0            200.0          2015.0
# 8         60.0             90           61.0             87.0          2021.0
# 9         64.0             89           72.0             80.0          2019.0
# 10        63.0             81           62.0             95.0          2021.0
# 11        66.0             95           77.0             90.0          2020.0
# 12        60.0             88           73.0             91.0          2020.0
# 13        72.0             80           69.0             98.0          2021.0
# 14        60.0             76           69.0             82.0          2020.0
# 15        69.0             83           69.0              NaN          2019.0
# 16        72.0             80           20.0             75.0          2021.0
# 17        90.0             95           66.0             85.0          2002.0
# 18        70.0             89           73.0             90.0          2020.0
# 19        66.0             91           77.0            100.0          2020.0
# 20        61.0             75           74.0             76.0             NaN
# 21        63.0             77           79.0             82.0          2018.0
# 22        65.0             95           60.0            100.0          2021.0
# 23        63.0             86           78.0             82.0          2019.0
# 24        78.0             95           66.0              NaN          2019.0
# 25        71.0             84           72.0             89.0          2018.0
# 26        78.0             78           73.0             87.0          2018.0
# 27        67.0             79           67.0             89.0          2018.0
# 28        75.0             79           67.0             97.0          2020.0
# 29        73.0             78           67.0             75.0          2020.0
#
#     placement_offer_count
# 0                     3.0
# 1                     3.0
# 2                     2.0
# 3                     2.0
# 4                     2.0
# 5                     3.0
# 6                     3.0
# 7                     3.0
# 8                     3.0
# 9                     2.0
# 10                    1.0
# 11                    3.0
# 12                    3.0
# 13                    3.0
# 14                    2.0
# 15                    1.0
# 16                    2.0
# 17                    NaN
# 18                    3.0
# 19                    3.0
# 20                    2.0
# 21                    3.0
# 22                    3.0
# 23                    2.0
# 24                    1.0
# 25                    3.0
# 26                    3.0
# 27                    3.0
# 28                    3.0
# 29                    2.0

# %%
df.isnull().sum()
# Out:
# math_score               0
# reading_score            0
# writing_score            0
# placement_score          2
# club_join_date           2
# placement_offer_count    1
# dtype: int64

# %%
df['placement_score'] = df['placement_score'].fillna(method='bfill')
df
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_date  \
# 0         71.0             78           65.0             99.0          2018.0
# 1         63.0             86           71.0            100.0             NaN
# 2         71.0             92           64.0             76.0          2021.0
# 3         77.0             95           68.0             84.0          2021.0
# 4         63.0             81           70.0             76.0          2021.0
# 5         64.5             92           70.0             89.0          2020.0
# 6         66.0             75           67.0             93.0          2019.0
# 7         50.0            100           68.0            200.0          2015.0
# 8         60.0             90           61.0             87.0          2021.0
# 9         64.0             89           72.0             80.0          2019.0
# 10        63.0             81           62.0             95.0          2021.0
# 11        66.0             95           77.0             90.0          2020.0
# 12        60.0             88           73.0             91.0          2020.0
# 13        72.0             80           69.0             98.0          2021.0
# 14        60.0             76           69.0             82.0          2020.0
# 15        69.0             83           69.0             75.0          2019.0
# 16        72.0             80           20.0             75.0          2021.0
# 17        90.0             95           66.0             85.0          2002.0
# 18        70.0             89           73.0             90.0          2020.0
# 19        66.0             91           77.0            100.0          2020.0
# 20        61.0             75           74.0             76.0             NaN
# 21        63.0             77           79.0             82.0          2018.0
# 22        65.0             95           60.0            100.0          2021.0
# 23        63.0             86           78.0             82.0          2019.0
# 24        78.0             95           66.0             89.0          2019.0
# 25        71.0             84           72.0             89.0          2018.0
# 26        78.0             78           73.0             87.0          2018.0
# 27        67.0             79           67.0             89.0          2018.0
# 28        75.0             79           67.0             97.0          2020.0
# 29        73.0             78           67.0             75.0          2020.0
#
#     placement_offer_count
# 0                     3.0
# 1                     3.0
# 2                     2.0
# 3                     2.0
# 4                     2.0
# 5                     3.0
# 6                     3.0
# 7                     3.0
# 8                     3.0
# 9                     2.0
# 10                    1.0
# 11                    3.0
# 12                    3.0
# 13                    3.0
# 14                    2.0
# 15                    1.0
# 16                    2.0
# 17                    NaN
# 18                    3.0
# 19                    3.0
# 20                    2.0
# 21                    3.0
# 22                    3.0
# 23                    2.0
# 24                    1.0
# 25                    3.0
# 26                    3.0
# 27                    3.0
# 28                    3.0
# 29                    2.0

# %%
df.isnull().sum()
# Out:
# math_score               0
# reading_score            0
# writing_score            0
# placement_score          0
# club_join_date           2
# placement_offer_count    1
# dtype: int64

# %%
df['club_join_date'] = df['club_join_date'].replace(to_replace=np.nan,value='2019')
df
# Out:
#     math_score  reading_score  writing_score  placement_score club_join_date  \
# 0         71.0             78           65.0             99.0         2018.0
# 1         63.0             86           71.0            100.0           2019
# 2         71.0             92           64.0             76.0         2021.0
# 3         77.0             95           68.0             84.0         2021.0
# 4         63.0             81           70.0             76.0         2021.0
# 5         64.5             92           70.0             89.0         2020.0
# 6         66.0             75           67.0             93.0         2019.0
# 7         50.0            100           68.0            200.0         2015.0
# 8         60.0             90           61.0             87.0         2021.0
# 9         64.0             89           72.0             80.0         2019.0
# 10        63.0             81           62.0             95.0         2021.0
# 11        66.0             95           77.0             90.0         2020.0
# 12        60.0             88           73.0             91.0         2020.0
# 13        72.0             80           69.0             98.0         2021.0
# 14        60.0             76           69.0             82.0         2020.0
# 15        69.0             83           69.0             75.0         2019.0
# 16        72.0             80           20.0             75.0         2021.0
# 17        90.0             95           66.0             85.0         2002.0
# 18        70.0             89           73.0             90.0         2020.0
# 19        66.0             91           77.0            100.0         2020.0
# 20        61.0             75           74.0             76.0           2019
# 21        63.0             77           79.0             82.0         2018.0
# 22        65.0             95           60.0            100.0         2021.0
# 23        63.0             86           78.0             82.0         2019.0
# 24        78.0             95           66.0             89.0         2019.0
# 25        71.0             84           72.0             89.0         2018.0
# 26        78.0             78           73.0             87.0         2018.0
# 27        67.0             79           67.0             89.0         2018.0
# 28        75.0             79           67.0             97.0         2020.0
# 29        73.0             78           67.0             75.0         2020.0
#
#     placement_offer_count
# 0                     3.0
# 1                     3.0
# 2                     2.0
# 3                     2.0
# 4                     2.0
# 5                     3.0
# 6                     3.0
# 7                     3.0
# 8                     3.0
# 9                     2.0
# 10                    1.0
# 11                    3.0
# 12                    3.0
# 13                    3.0
# 14                    2.0
# 15                    1.0
# 16                    2.0
# 17                    NaN
# 18                    3.0
# 19                    3.0
# 20                    2.0
# 21                    3.0
# 22                    3.0
# 23                    2.0
# 24                    1.0
# 25                    3.0
# 26                    3.0
# 27                    3.0
# 28                    3.0
# 29                    2.0

# %%
df.isnull().sum()
# Out:
# math_score               0
# reading_score            0
# writing_score            0
# placement_score          0
# club_join_date           0
# placement_offer_count    1
# dtype: int64

# %%
df['placement_offer_count']=df['placement_offer_count'].fillna('1')
df
# Out:
#     math_score  reading_score  writing_score  placement_score club_join_date  \
# 0         71.0             78           65.0             99.0         2018.0
# 1         63.0             86           71.0            100.0           2019
# 2         71.0             92           64.0             76.0         2021.0
# 3         77.0             95           68.0             84.0         2021.0
# 4         63.0             81           70.0             76.0         2021.0
# 5         64.5             92           70.0             89.0         2020.0
# 6         66.0             75           67.0             93.0         2019.0
# 7         50.0            100           68.0            200.0         2015.0
# 8         60.0             90           61.0             87.0         2021.0
# 9         64.0             89           72.0             80.0         2019.0
# 10        63.0             81           62.0             95.0         2021.0
# 11        66.0             95           77.0             90.0         2020.0
# 12        60.0             88           73.0             91.0         2020.0
# 13        72.0             80           69.0             98.0         2021.0
# 14        60.0             76           69.0             82.0         2020.0
# 15        69.0             83           69.0             75.0         2019.0
# 16        72.0             80           20.0             75.0         2021.0
# 17        90.0             95           66.0             85.0         2002.0
# 18        70.0             89           73.0             90.0         2020.0
# 19        66.0             91           77.0            100.0         2020.0
# 20        61.0             75           74.0             76.0           2019
# 21        63.0             77           79.0             82.0         2018.0
# 22        65.0             95           60.0            100.0         2021.0
# 23        63.0             86           78.0             82.0         2019.0
# 24        78.0             95           66.0             89.0         2019.0
# 25        71.0             84           72.0             89.0         2018.0
# 26        78.0             78           73.0             87.0         2018.0
# 27        67.0             79           67.0             89.0         2018.0
# 28        75.0             79           67.0             97.0         2020.0
# 29        73.0             78           67.0             75.0         2020.0
#
#    placement_offer_count
# 0                    3.0
# 1                    3.0
# 2                    2.0
# 3                    2.0
# 4                    2.0
# 5                    3.0
# 6                    3.0
# 7                    3.0
# 8                    3.0
# 9                    2.0
# 10                   1.0
# 11                   3.0
# 12                   3.0
# 13                   3.0
# 14                   2.0
# 15                   1.0
# 16                   2.0
# 17                     1
# 18                   3.0
# 19                   3.0
# 20                   2.0
# 21                   3.0
# 22                   3.0
# 23                   2.0
# 24                   1.0
# 25                   3.0
# 26                   3.0
# 27                   3.0
# 28                   3.0
# 29                   2.0

# %%
df.isnull().sum()
# Out:
# math_score               0
# reading_score            0
# writing_score            0
# placement_score          0
# club_join_date           0
# placement_offer_count    0
# dtype: int64

# %% [markdown]
# # Check the data types and convert into appropriate types

# %%
df.dtypes
# Out:
# math_score               float64
# reading_score              int64
# writing_score            float64
# placement_score          float64
# club_join_date            object
# placement_offer_count     object
# dtype: object

# %%
df['math_score']=df['math_score'].astype('int64')
df['reading_score']=df['reading_score'].astype('int64')
df['writing_score']=df['writing_score'].astype('int64')
df['placement_score']=df['placement_score'].astype('int64')
df['club_join_date']=df['club_join_date'].astype('int64')
df['placement_offer_count']=df['placement_offer_count'].astype('int64')
df.dtypes
# Out:
# math_score               int64
# reading_score            int64
# writing_score            int64
# placement_score          int64
# club_join_date           int64
# placement_offer_count    int64
# dtype: object

# %% [markdown]
# # Check for outliers

# %%
columns = ['math_score','reading_score','writing_score','placement_score']
df.boxplot(columns)
# Out:
# <Axes: >

# %%
Q1 = df['math_score'].quantile(0.25)
Q3 = df['math_score'].quantile(0.75)
IQR = Q3 - Q1
lower_lim = Q1 - 1.5*IQR
upper_lim = Q3 + 1.5*IQR

# %%
np.where(df['math_score'] < 60)
# Out:
# (array([7]),)

# %%
np.where(df['math_score'] > 80)
# Out:
# (array([17]),)

# %%
np.where(df['reading_score'] < 75)
# Out:
# (array([], dtype=int64),)

# %%
np.where(df['reading_score'] > 95)
# Out:
# (array([7]),)

# %%
np.where(df['writing_score'] < 60)
# Out:
# (array([16]),)

# %%
np.where(df['writing_score'] > 80)
# Out:
# (array([], dtype=int64),)

# %%
np.where(df['placement_score'] < 75)
# Out:
# (array([], dtype=int64),)

# %%
np.where(df['placement_score'] > 100)
# Out:
# (array([7]),)

# %%
np.where((df['placement_score'] < 75) & (df['placement_offer_count'] > 1))
# Out:
# (array([], dtype=int64),)

# %%
np.where(((df['placement_score'] > 75) & (df['placement_score'] <= 85)) 
         & ((df['placement_offer_count'] > 2) | (df['placement_offer_count'] < 2) ))
# Out:
# (array([17, 21]),)

# %%
np.where((df['placement_score'] > 85) & (df['placement_offer_count'] < 3))
# Out:
# (array([10, 24]),)

# %%
# The above results gives us the rows with the outliers
# There are different methods that can be used for outlier detection and removal
# 1. Percentile
# 2. Standard Deviation
# 3. Z score
# 4. IQR - Inter quartile range

# %% [markdown]
# # Outlier detection

# %%
df[(df['math_score'] < 60) | (df['math_score'] > 80)]
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_date  \
# 7           50            100             68              200            2015
# 17          90             95             66               85            2002
#
#     placement_offer_count
# 7                       3
# 17                      1

# %%
df[(df['reading_score'] < 75) | (df['reading_score'] > 95)]
# Out:
#    math_score  reading_score  writing_score  placement_score  club_join_date  \
# 7          50            100             68              200            2015
#
#    placement_offer_count
# 7                      3

# %%
df[(df['writing_score'] < 60) | (df['writing_score'] > 80)]
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_date  \
# 16          72             80             20               75            2021
#
#     placement_offer_count
# 16                      2

# %%
df[(df['placement_score'] < 75) | (df['placement_score'] > 100)]
# Out:
#    math_score  reading_score  writing_score  placement_score  club_join_date  \
# 7          50            100             68              200            2015
#
#    placement_offer_count
# 7                      3

# %%
df[(df['club_join_date'] < 2018) | (df['club_join_date'] > 2021)]
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_date  \
# 7           50            100             68              200            2015
# 17          90             95             66               85            2002
#
#     placement_offer_count
# 7                       3
# 17                      1

# %%
df[(df['placement_score'] < 75) & (df['placement_offer_count'] > 1)]
# Out:
# Empty DataFrame
# Columns: [math_score, reading_score, writing_score, placement_score, club_join_date, placement_offer_count]
# Index: []

# %%
df[((df['placement_score'] > 75) & (df['placement_score'] <= 85)) 
   & ((df['placement_offer_count'] > 2) | (df['placement_offer_count'] < 2))]
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_date  \
# 17          90             95             66               85            2002
# 21          63             77             79               82            2018
#
#     placement_offer_count
# 17                      1
# 21                      3

# %%
df[((df['placement_score'] > 85) & (df['placement_offer_count'] < 3))]
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_date  \
# 10          63             81             62               95            2021
# 24          78             95             66               89            2019
#
#     placement_offer_count
# 10                      1
# 24                      1

# %% [markdown]
# # Outlier Removal

# %%
new_df1 = df[
    ((df.math_score >= 60) & (df.math_score <= 80)) &
    ((df.reading_score >= 75) & (df.reading_score <= 95)) &
    ((df.writing_score >= 60) & (df.writing_score <= 80)) &
    ((df.placement_score >= 75) & (df.placement_score <= 100)) &
    ((df.club_join_date >= 2018) & (df.club_join_date <= 2021))]

new_df1
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_date  \
# 0           71             78             65               99            2018
# 1           63             86             71              100            2019
# 2           71             92             64               76            2021
# 3           77             95             68               84            2021
# 4           63             81             70               76            2021
# 5           64             92             70               89            2020
# 6           66             75             67               93            2019
# 8           60             90             61               87            2021
# 9           64             89             72               80            2019
# 10          63             81             62               95            2021
# 11          66             95             77               90            2020
# 12          60             88             73               91            2020
# 13          72             80             69               98            2021
# 14          60             76             69               82            2020
# 15          69             83             69               75            2019
# 18          70             89             73               90            2020
# 19          66             91             77              100            2020
# 20          61             75             74               76            2019
# 21          63             77             79               82            2018
# 22          65             95             60              100            2021
# 23          63             86             78               82            2019
# 24          78             95             66               89            2019
# 25          71             84             72               89            2018
# 26          78             78             73               87            2018
# 27          67             79             67               89            2018
# 28          75             79             67               97            2020
# 29          73             78             67               75            2020
#
#     placement_offer_count
# 0                       3
# 1                       3
# 2                       2
# 3                       2
# 4                       2
# 5                       3
# 6                       3
# 8                       3
# 9                       2
# 10                      1
# 11                      3
# 12                      3
# 13                      3
# 14                      2
# 15                      1
# 18                      3
# 19                      3
# 20                      2
# 21                      3
# 22                      3
# 23                      2
# 24                      1
# 25                      3
# 26                      3
# 27                      3
# 28                      3
# 29                      2

# %%
new_df1[(new_df1['placement_score'] < 75) & (new_df1['placement_offer_count'] > 1)]
# Out:
# Empty DataFrame
# Columns: [math_score, reading_score, writing_score, placement_score, club_join_date, placement_offer_count]
# Index: []

# %%
new_df1[((new_df1['placement_score'] >= 75) & (new_df1['placement_score'] <= 85)) 
   & ((new_df1['placement_offer_count'] > 2) | (new_df1['placement_offer_count'] < 2))]
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_date  \
# 15          69             83             69               75            2019
# 21          63             77             79               82            2018
#
#     placement_offer_count
# 15                      1
# 21                      3

# %%
new_df1[((new_df1['placement_score'] > 85) & (new_df1['placement_offer_count'] < 3))]
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_date  \
# 10          63             81             62               95            2021
# 24          78             95             66               89            2019
#
#     placement_offer_count
# 10                      1
# 24                      1

# %%
new_df2 = new_df1[
    ((new_df1.placement_score < 75) & (new_df1.placement_offer_count==1)) |
    (((new_df1.placement_score >= 75) & (new_df1.placement_score <= 85)) & (new_df1.placement_offer_count==2)) |
    ((new_df1.placement_score > 85) & (new_df1.placement_offer_count==3))]

new_df2
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_date  \
# 0           71             78             65               99            2018
# 1           63             86             71              100            2019
# 2           71             92             64               76            2021
# 3           77             95             68               84            2021
# 4           63             81             70               76            2021
# 5           64             92             70               89            2020
# 6           66             75             67               93            2019
# 8           60             90             61               87            2021
# 9           64             89             72               80            2019
# 11          66             95             77               90            2020
# 12          60             88             73               91            2020
# 13          72             80             69               98            2021
# 14          60             76             69               82            2020
# 18          70             89             73               90            2020
# 19          66             91             77              100            2020
# 20          61             75             74               76            2019
# 22          65             95             60              100            2021
# 23          63             86             78               82            2019
# 25          71             84             72               89            2018
# 26          78             78             73               87            2018
# 27          67             79             67               89            2018
# 28          75             79             67               97            2020
# 29          73             78             67               75            2020
#
#     placement_offer_count
# 0                       3
# 1                       3
# 2                       2
# 3                       2
# 4                       2
# 5                       3
# 6                       3
# 8                       3
# 9                       2
# 11                      3
# 12                      3
# 13                      3
# 14                      2
# 18                      3
# 19                      3
# 20                      2
# 22                      3
# 23                      2
# 25                      3
# 26                      3
# 27                      3
# 28                      3
# 29                      2

# %%
new_df2.shape
# Out:
# (23, 6)

# %% [markdown]
# # Check if the outliers are completely removed

# %%
new_df2[(new_df2['math_score'] < 60) | (new_df2['math_score'] > 80)]
# Out:
# Empty DataFrame
# Columns: [math_score, reading_score, writing_score, placement_score, club_join_date, placement_offer_count]
# Index: []

# %%
new_df2[(new_df2['reading_score'] < 75) | (new_df2['reading_score'] > 95)]
# Out:
# Empty DataFrame
# Columns: [math_score, reading_score, writing_score, placement_score, club_join_date, placement_offer_count]
# Index: []

# %%
new_df2[(new_df2['writing_score'] < 60) | (new_df2['writing_score'] > 80)]
# Out:
# Empty DataFrame
# Columns: [math_score, reading_score, writing_score, placement_score, club_join_date, placement_offer_count]
# Index: []

# %%
new_df2[(new_df2['placement_score'] < 75) | (new_df2['placement_score'] > 100)]
# Out:
# Empty DataFrame
# Columns: [math_score, reading_score, writing_score, placement_score, club_join_date, placement_offer_count]
# Index: []

# %%
new_df2[(new_df2['club_join_date'] < 2018) | (new_df2['club_join_date'] > 2021)]
# Out:
# Empty DataFrame
# Columns: [math_score, reading_score, writing_score, placement_score, club_join_date, placement_offer_count]
# Index: []

# %%
new_df2[(new_df2['placement_score'] < 75) & (new_df2['placement_offer_count'] > 1)]
# Out:
# Empty DataFrame
# Columns: [math_score, reading_score, writing_score, placement_score, club_join_date, placement_offer_count]
# Index: []

# %%
new_df2[((new_df2['placement_score'] > 75) & (new_df2['placement_score'] <= 85)) 
   & ((new_df2['placement_offer_count'] > 2) | (new_df2['placement_offer_count'] < 2))]
# Out:
# Empty DataFrame
# Columns: [math_score, reading_score, writing_score, placement_score, club_join_date, placement_offer_count]
# Index: []

# %%
new_df2[((new_df2['placement_score'] > 85) & (new_df2['placement_offer_count'] < 3))]
# Out:
# Empty DataFrame
# Columns: [math_score, reading_score, writing_score, placement_score, club_join_date, placement_offer_count]
# Index: []

# %%
columns = ['math_score','reading_score','writing_score','placement_score']
new_df2.boxplot(columns)
# Out:
# <Axes: >

# %% [markdown]
# # Data transformation and Normalization

# %%
from sklearn.preprocessing import StandardScaler
scaling = StandardScaler()
scaling.fit_transform(new_df2[['math_score','reading_score','writing_score','placement_score']])
# Out:
# array([[ 0.70724695, -1.01351511, -1.02007353,  1.31565504],
#        [-0.78853971,  0.17429878,  0.27139571,  1.43816543],
#        [ 0.70724695,  1.06515919, -1.2353184 , -1.5020839 ],
#        [ 1.82908695,  1.51058939, -0.37433891, -0.52200079],
#        [-0.78853971, -0.5680849 ,  0.05615084, -1.5020839 ],
#        [-0.60156638,  1.06515919,  0.05615084,  0.09055116],
#        [-0.22761971, -1.45894531, -0.58958378,  0.58059271],
#        [-1.34945971,  0.76820572, -1.88105303, -0.15446962],
#        [-0.60156638,  0.61972898,  0.48664058, -1.01204234],
#        [-0.22761971,  1.51058939,  1.56286495,  0.21306155],
#        [-1.34945971,  0.47125225,  0.70188546,  0.33557193],
#        [ 0.89422029, -0.71656164, -0.15909404,  1.19314465],
#        [-1.34945971, -1.31046858, -0.15909404, -0.76702156],
#        [ 0.52027362,  0.61972898,  0.70188546,  0.21306155],
#        [-0.22761971,  0.91668245,  1.56286495,  1.43816543],
#        [-1.16248637, -1.45894531,  0.91713033, -1.5020839 ],
#        [-0.41459304,  1.51058939, -2.0962979 ,  1.43816543],
#        [-0.78853971,  0.17429878,  1.77810982, -0.76702156],
#        [ 0.70724695, -0.12265469,  0.48664058,  0.09055116],
#        [ 2.01606029, -1.01351511,  0.70188546, -0.15446962],
#        [-0.04064638, -0.86503837, -0.58958378,  0.09055116],
#        [ 1.45514029, -0.86503837, -0.58958378,  1.07063427],
#        [ 1.08119362, -1.01351511, -0.58958378, -1.62459428]])
